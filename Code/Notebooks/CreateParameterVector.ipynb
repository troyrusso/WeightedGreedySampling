# %% [markdown]
# # Packages

# %%
### Import packages ###
import itertools
import numpy as np
import pandas as pd
import sys
sys.path.append('..')
from utils.Auxiliary import CreateParameterVectorFunction
from utils.Auxiliary import FilterJobNames

# %% [markdown]
# ---

# %% [markdown]
# # Create Parameter Vector

# %%
# Done: Iris, MONK1, MONK3, Haberman
# Need medium: FICO, COMPAS
# Running: BankNote, BreastCancer
# No Status: CarEvaluation

# %%
# Data: Iris  MONK1  MONK3  Bar7 (10)  COMPAS (50) | BankNote (10)  BreastCancer (5)  CarEvaluation (10)  FICO (50)  Haberman
Data = "Iris"
ParameterVector = CreateParameterVectorFunction(Data = Data,
                                  Seed = range(0,50),                     # range(0,50)
                                  RashomonThreshold = 0.05,        # For TreeFarms
                                  DiversityWeight = 0,          # For BatchQBC
                                  DensityWeight = 0,            # For BatchQBC
                                  BatchSize = 1,                           # 1 5 or 10
                                  Partition = "short",                                # [short, medium, long, largemem, compute, cpu-g2-mem2x]
                                  Time = "11:59:00",                                     # [00:59:00, 11:59:00, 6-23:59:00]
                                  Memory = "30000M",                                   # [100M, 30000M, 100000M]
                                  IncludePL_RF=False,       # Passive Learning with RandomForestClassifierPredictor
                                  IncludePL_GPC=False,      # Passive Learning with GaussianProcessClassifierPredictor
                                  IncludePL_BNN=False,      # Passive Learning with BayesianNeuralNetworkPredictor
                                  IncludeBALD_BNN=False,    # BALD with BayesianNeuralNetworkPredictor
                                  IncludeBALD_GPC=False,    # BALD with GaussianProcessClassifierPredictor
                                  IncludeQBC_TreeFarms_Unique=False, # BatchQBC with TreeFarmsPredictor (UniqueErrorsInput=1)
                                  IncludeQBC_TreeFarms_Duplicate=False, # BatchQBC with TreeFarmsPredictor (UniqueErrorsInput=0)
                                  IncludeQBC_RF=False,      # BatchQBC with RandomForestClassifierPredictor
                                  IncludeLFR_TreeFarms_Unique=True, #BatchQBC with LFRPredictor (UniqueErrorsInput=1)
                                  IncludeLFR_TreeFarms_Duplicate=True, #BatchQBC with LFRPredictor (UniqueErrorsInput=0)
                                  auto_tune_epsilon_for_lfr=False 
                                  )

# %% [markdown]
# # Evaluate

# %%
ParameterVector
# Out:
#     BatchSize  CandidateProportion  Data  DensityWeight  DiversityWeight  \
# 0           1                  0.8  Iris              0                0
# 1           1                  0.8  Iris              0                0
# 2           1                  0.8  Iris              0                0
# 3           1                  0.8  Iris              0                0
# 4           1                  0.8  Iris              0                0
# ..        ...                  ...   ...            ...              ...
# 95          1                  0.8  Iris              0                0
# 96          1                  0.8  Iris              0                0
# 97          1                  0.8  Iris              0                0
# 98          1                  0.8  Iris              0                0
# 99          1                  0.8  Iris              0                0
#
#     Memory     ModelType Partition  RashomonThreshold RashomonThresholdType  \
# 0   30000M  LFRPredictor     short               0.05                 Adder
# 1   30000M  LFRPredictor     short               0.05                 Adder
# 2   30000M  LFRPredictor     short               0.05                 Adder
# 3   30000M  LFRPredictor     short               0.05                 Adder
# 4   30000M  LFRPredictor     short               0.05                 Adder
# ..     ...           ...       ...                ...                   ...
# 95  30000M  LFRPredictor     short               0.05                 Adder
# 96  30000M  LFRPredictor     short               0.05                 Adder
# 97  30000M  LFRPredictor     short               0.05                 Adder
# 98  30000M  LFRPredictor     short               0.05                 Adder
# 99  30000M  LFRPredictor     short               0.05                 Adder
#
#     ...  TestProportion      Time            Type UniqueErrorsInput  \
# 0   ...             0.2  11:59:00  Classification                 1
# 1   ...             0.2  11:59:00  Classification                 0
# 2   ...             0.2  11:59:00  Classification                 1
# 3   ...             0.2  11:59:00  Classification                 0
# 4   ...             0.2  11:59:00  Classification                 1
# ..  ...             ...       ...             ...               ...
# 95  ...             0.2  11:59:00  Classification                 1
# 96  ...             0.2  11:59:00  Classification                 0
# 97  ...             0.2  11:59:00  Classification                 1
# 98  ...             0.2  11:59:00  Classification                 1
# 99  ...             0.2  11:59:00  Classification                 0
#
#    auto_tune_epsilon  n_estimators  regularization     MethodName  \
# 0              False           100            0.01  Ulfr_AT0_UEI1
# 1              False           100            0.01  Dlfr_AT0_UEI0
# 2              False           100            0.01  Ulfr_AT0_UEI1
# 3              False           100            0.01  Dlfr_AT0_UEI0
# 4              False           100            0.01  Ulfr_AT0_UEI1
# ..               ...           ...             ...            ...
# 95             False           100            0.01  Ulfr_AT0_UEI1
# 96             False           100            0.01  Dlfr_AT0_UEI0
# 97             False           100            0.01  Ulfr_AT0_UEI1
# 98             False           100            0.01  Ulfr_AT0_UEI1
# 99             False           100            0.01  Dlfr_AT0_UEI0
#
#                                JobName  \
# 0    0IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 1    0IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 2    1IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 3    1IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 4    2IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# ..                                 ...
# 95  47IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 96  48IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 97  48IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 98  49IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 99  49IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
#
#                                                Output
# 0   Iris/LFRPredictor/Raw/0IS_Ulfr_AT0_UEI1_A05_DW...
# 1   Iris/LFRPredictor/Raw/0IS_Dlfr_AT0_UEI0_A05_DW...
# 2   Iris/LFRPredictor/Raw/1IS_Ulfr_AT0_UEI1_A05_DW...
# 3   Iris/LFRPredictor/Raw/1IS_Dlfr_AT0_UEI0_A05_DW...
# 4   Iris/LFRPredictor/Raw/2IS_Ulfr_AT0_UEI1_A05_DW...
# ..                                                ...
# 95  Iris/LFRPredictor/Raw/47IS_Ulfr_AT0_UEI1_A05_D...
# 96  Iris/LFRPredictor/Raw/48IS_Dlfr_AT0_UEI0_A05_D...
# 97  Iris/LFRPredictor/Raw/48IS_Ulfr_AT0_UEI1_A05_D...
# 98  Iris/LFRPredictor/Raw/49IS_Ulfr_AT0_UEI1_A05_D...
# 99  Iris/LFRPredictor/Raw/49IS_Dlfr_AT0_UEI0_A05_D...
#
# [100 rows x 22 columns]

# %%
ParameterVector["JobName"]
# Out:
# 0      0IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 1      0IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 2      1IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 3      1IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 4      2IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
#                      ...
# 95    47IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 96    48IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# 97    48IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 98    49IS_Ulfr_AT0_UEI1_A05_DW0_DEW0_B1
# 99    49IS_Dlfr_AT0_UEI0_A05_DW0_DEW0_B1
# Name: JobName, Length: 100, dtype: object

# %%
ParameterVector["Output"]
# Out:
# 0     Iris/LFRPredictor/Raw/0IS_Ulfr_AT0_UEI1_A05_DW...
# 1     Iris/LFRPredictor/Raw/0IS_Dlfr_AT0_UEI0_A05_DW...
# 2     Iris/LFRPredictor/Raw/1IS_Ulfr_AT0_UEI1_A05_DW...
# 3     Iris/LFRPredictor/Raw/1IS_Dlfr_AT0_UEI0_A05_DW...
# 4     Iris/LFRPredictor/Raw/2IS_Ulfr_AT0_UEI1_A05_DW...
#                             ...
# 95    Iris/LFRPredictor/Raw/47IS_Ulfr_AT0_UEI1_A05_D...
# 96    Iris/LFRPredictor/Raw/48IS_Dlfr_AT0_UEI0_A05_D...
# 97    Iris/LFRPredictor/Raw/48IS_Ulfr_AT0_UEI1_A05_D...
# 98    Iris/LFRPredictor/Raw/49IS_Ulfr_AT0_UEI1_A05_D...
# 99    Iris/LFRPredictor/Raw/49IS_Dlfr_AT0_UEI0_A05_D...
# Name: Output, Length: 100, dtype: object

# %% [markdown]
# # Only run these ones

# %%
# # ### Simulations that failed ###
# FilterText = ['26B7_UA02']
# ParameterVector = FilterJobNames(ParameterVector,FilterText)
# ParameterVector.index = range(0,len(ParameterVector))
# ParameterVector

# %% [markdown]
# ---

# %% [markdown]
# # Save Parameter Vector

# %%
### Resave ###
output_path = "/Users/simondn/Documents/RashomonActiveLearning/Data/ParameterVectors/ParameterVector" + str(Data) + ".csv"
ParameterVector.to_csv(output_path, index=False)
