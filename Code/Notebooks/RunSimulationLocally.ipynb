# %%
### Import packages ###
import time
import numpy as np
import math as math
import pandas as pd
import random as random

### Append Path ###
import sys
sys.path.append('..')

### Import functions ###
from utils.Main import *
from utils.Selector import *
from utils.Auxiliary import *
from utils.Prediction import *

# %% [markdown]
# # Inputs

# %%
### Input ###
NSim_input = 3
machine_learning_model_input = 'LinearRegressionPredictor'
test_proportion_input = 0.2
candidate_proportion_input = 0.8

### Get Directory ###
cwd = os.getcwd()
ParentDirectory = os.path.abspath(os.path.join(cwd, "..",".."))
DataDirectory = os.path.join(ParentDirectory,"Data","processed")

### Get Data Files ###
data_list = [f for f in os.listdir(DataDirectory) if f.endswith('.pkl')]
data_list = [s.rstrip(".pkl") for s in data_list] 
data_list
# Out:
# ['concrete_cs',
#  'pm10',
#  'wine_red',
#  'cps',
#  'bodyfat',
#  'concrete_4',
#  'beer',
#  'qsar',
#  'mpg',
#  'housing',
#  'concrete_flow',
#  'yacht',
#  'wine_white',
#  'no2',
#  'concrete_slum']

# %% [markdown]
# ## Graph Parameters

# %%
### Labels ###
Y_Label = "RMSE"
PlotSubtitle = "Active Learning Performance Comparison on MPG Dataset"


### Colors ###
colors = {
    # Original methods with distinct colors
    'Passive Learning': 'gray',
    'GSx': 'cornflowerblue',
    'GSy': 'salmon',
    'iGS': 'red',

    # WiGS Static methods in shades of green to group them
    'WiGS (Static w_x=0.75)': 'lightgreen',
    'WiGS (Static w_x=0.5)': 'forestgreen',
    'WiGS (Static w_x=0.25)': 'darkgreen',

    # WiGS Time-Decay methods in shades of orange/brown
    'WiGS (Time-Decay, Linear)': 'orange',
    'WiGS (Time-Decay, Exponential)': 'saddlebrown'
}

### Line styles ###
linestyles = {
    'Passive Learning': ':',
    'GSx': ':',
    'GSy': ':',
    'iGS': '-',
    'WiGS (Static w_x=0.75)': '-',
    'WiGS (Static w_x=0.5)': '-.',
    'WiGS (Static w_x=0.25)': '--',
    'WiGS (Time-Decay, Linear)': '-',
    'WiGS (Time-Decay, Exponential)': '-.'
}

### Legend ###
LegendMapping = {
    'Passive Learning': 'Random',
    'GSx': 'GSx',
    'GSy': 'GSy',
    'iGS': 'iGS',
    'WiGS (Static w_x=0.75)': 'WiGS (Static, w_x=0.75)',
    'WiGS (Static w_x=0.5)': 'WiGS (Static, w_x=0.5)',
    'WiGS (Static w_x=0.25)': 'WiGS (Static, w_x=0.25)',
    'WiGS (Time-Decay, Linear)': 'WiGS (Linear Decay)',
    'WiGS (Time-Decay, Exponential)': 'WiGS (Exponential Decay)'
}

### Plots ###
strategies_to_plot = [
    ### Original Methods ###
    # 'Passive Learning',
    # 'GSx',
    # 'GSy',
    'iGS',

    # ### WIGS Methods (Static) ###
    # 'WiGS (Static w_x=0.25)',  # Favors exploration (GSx)
    # 'WiGS (Static w_x=0.5)',   # Balanced approach
    'WiGS (Static w_x=0.75)',  # Favors exploitation (GSy)

    ### WiGS Methods (Time-decayed) ###
    'WiGS (Time-Decay, Linear)',
    'WiGS (Time-Decay, Exponential)',
    ]

# %% [markdown]
# ## Graph Inputs

# %%
for dat in data_list:

    ### Get Dataframe ###
    DataFileInput = dat
    print("Data: " + str(DataFileInput))

    ### Run Simulation ###
    all_results = RunSimulationFunction(DataFileInput = DataFileInput,
                                    NSim = NSim_input,
                                    machine_learning_model = machine_learning_model_input,
                                    test_proportion = test_proportion_input,
                                    candidate_proportion = candidate_proportion_input)
    
    ### Filter results ###
    filtered_results_to_plot = {key: all_results[key] for key in strategies_to_plot if key in all_results}

    ### Create Plots ###
    TracePlotMean, TracePlotVariance = MeanVariancePlot(RelativeError=None,
                                                        Colors=colors,
                                                        LegendMapping=LegendMapping,
                                                        Linestyles=linestyles,
                                                        Y_Label=Y_Label,
                                                        Subtitle="Comparison of WiGS Strategies vs. iGS", 
                                                        TransparencyVal=0.00,
                                                        VarInput=True,
                                                        CriticalValue=1.96,
                                                        initial_train_proportion=0.16,
                                                        candidate_pool_proportion=0.64,
                                                        **filtered_results_to_plot
                                                        )
    
    # ### Save Simulations ###
    # file_path = os.path.join("/Users/simondn/Documents/WeightedGreedySampling/Results/simulation_results", f"{DataFileInput}_results.pkl")
    # with open(file_path, 'wb') as file:
    #     pickle.dump(all_results, file)
        
    # ### Save Trace Plot ###
    # trace_plot_path = os.path.join("/Users/simondn/Documents/WeightedGreedySampling/Results/images/trace", f"{DataFileInput}_TracePlot.png")
    # TracePlotMean.savefig(trace_plot_path, bbox_inches='tight', dpi=300)

    # ### Save Variance Plot ###
    # variance_plot_path = os.path.join("/Users/simondn/Documents/WeightedGreedySampling/Results/images/variance", f"{DataFileInput}_VariancePlot.png")
    # TracePlotVariance.savefig(variance_plot_path, bbox_inches='tight', dpi=300)
# Out:
# Data: concrete_cs
#
# --- Running Simulations for: Passive Learning ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 16.01it/s]
# --- Running Simulations for: GSx ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 14.77it/s]
# --- Running Simulations for: GSy ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.66it/s]
# --- Running Simulations for: iGS ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.52it/s]
# --- Running Simulations for: WiGS (Static w_x=0.25) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.26it/s]
# --- Running Simulations for: WiGS (Static w_x=0.5) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 11.51it/s]
# --- Running Simulations for: WiGS (Static w_x=0.75) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 11.19it/s]
# --- Running Simulations for: WiGS (Time-Decay, Linear) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.11it/s]
# --- Running Simulations for: WiGS (Time-Decay, Exponential) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.14it/s]
# --- Running Simulations for: WiGS (MAB-UCB1, c=0.5) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 11.62it/s]
# --- Running Simulations for: WiGS (MAB-UCB1, c=2.0) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.13it/s]
# --- Running Simulations for: WiGS (MAB-UCB1, c=5.0) ---
# Simulations: 100%|██████████| 3/3 [00:00<00:00, 12.32it/s]
# Data: pm10
#
# --- Running Simulations for: Passive Learning ---
# Simulations: 100%|██████████| 3/3 [00:06<00:00,  2.18s/it]
# --- Running Simulations for: GSx ---
# Simulations: 100%|██████████| 3/3 [00:27<00:00,  9.03s/it]
# --- Running Simulations for: GSy ---
# Simulations: 100%|██████████| 3/3 [00:24<00:00,  8.09s/it]
# --- Running Simulations for: iGS ---
# Simulations: 100%|██████████| 3/3 [00:53<00:00, 17.89s/it]
# --- Running Simulations for: WiGS (Static w_x=0.25) ---
# Simulations: 100%|██████████| 3/3 [01:35<00:00, 31.81s/it]
# --- Running Simulations for: WiGS (Static w_x=0.5) ---
# Simulations:   0%|          | 0/3 [00:00<?, ?it/s]
